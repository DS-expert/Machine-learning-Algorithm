# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme("paper")
sns.set_color_codes("deep")

# %%
# Load the dataset
df = pd.read_csv("/home/inventor/Datasets/House Prediction/House_Prediction/data.csv")

# %%
# Sample of dataset
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# Shape of dataset
df.shape
# Out:
# (4600, 18)

# %%
# Info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
# Description about dataset
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# Find the Missing Values 
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
# Find the duplicates value
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Explore the data

def explore_value_count(df, feature_name):

    if df[feature_name].dtype == "object":
        print(f"\n*********************************")
        print(f"{feature_name} Value Count: \n{df[feature_name].value_counts()}")
        print("\n************************************")

# %%
for feature in df.columns:

    explore_value_count(df, feature)
# Out:
# *********************************
# date Value Count:
# date
# 2014-06-23 00:00:00    142
# 2014-06-25 00:00:00    131
# 2014-06-26 00:00:00    131
# 2014-07-08 00:00:00    127
# 2014-07-09 00:00:00    121
#                       ...
# 2014-06-07 00:00:00      4
# 2014-07-06 00:00:00      3
# 2014-05-11 00:00:00      2
# 2014-07-04 00:00:00      2
# 2014-05-17 00:00:00      1
# Name: count, Length: 70, dtype: int64
#
# ************************************
#
# *********************************
# street Value Count:
# street
# 2520 Mulberry Walk NE    4
# 2500 Mulberry Walk NE    3
# 2803 SW Bataan St        2
# 8354 11th Ave NW         2
# 6008 8th Ave NE          2
#                         ..
# 25919 SE 37th Way        1
# 14435 SE 263rd St        1
# 2150 N 128th St          1
# 2043 NE 98th St          1
# 18923 SE 416th St        1
# Name: count, Length: 4525, dtype: int64
#
# ************************************
#
# *********************************
# city Value Count:
# city
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
# Replace datatypes of some feature
df["price"] = df["price"].astype("int")
df["bedrooms"] = df["bedrooms"].astype("int")
df["bathrooms"] = df["bathrooms"].astype("int")
df["floors"] = df["floors"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   int64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   int64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   int64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# ...

# %%
# Remove some feature to clean up the data
df = df.drop(columns=["date", "street", "statezip", "country"], axis=1)

# %%
df.head()
# Out:
#      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000         3          1         1340      7912       1           0
# 1  2384000         5          2         3650      9050       2           0
# 2   342000         3          2         1930     11947       1           0
# 3   420000         3          2         2000      8030       1           0
# 4   550000         4          2         1940     10500       1           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#         city
# 0  Shoreline
# 1    Seattle
# 2       Kent
# 3   Bellevue
# 4    Redmond

# %%
# Data Visualization 
# Price distribution

plt.figure(figsize=(10, 6))
sns.lineplot(df["price"])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="bedrooms", y="price")
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %%
# Sqft Living vs Price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="sqft_living", y="price")
plt.show()

# %%
# Bedrooms vs Bathrooms
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="bedrooms", y="bathrooms")
plt.show()

# %%
# Price Vs Bathrooms
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="bathrooms", y="price")
plt.show()

# %%
# Floor vs Price
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="floors", y="price")
plt.show()

# %%
# Price vs City
plt.figure(figsize=(20, 10))
sns.barplot(data=df, x="city", y="price")
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="sqft_lot", y="price")
plt.title('Price Vs Sqft_lot')
plt.show()

# %%
# Price vs sqft_above
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sqft_above', y="price")
plt.title("Price vs sqft_above")
plt.show()

# %%
# Prive vs Sqft_basement
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="sqft_basement", y="price")
plt.title("Price vs sqft_basement")
plt.show()

# %%
# Price vs Waterfront
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="waterfront", y="price")
plt.show()

# %%
# Price vs View
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="view", y="price")
plt.show()

# %%
# Price vs Condition
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="condition", y="price")
plt.show()

# %%
# Price vs year_built
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="yr_built", y="price")
plt.show()

# %%
# Price vs year_renovated
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="yr_renovated", y="price")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".1f", cmap=sns.color_palette("mako", as_cmap=True))
plt.show()

# %%
corr_matrix["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.430410
# sqft_above       0.367570
# bathrooms        0.317229
# view             0.228504
# sqft_basement    0.210427
# bedrooms         0.200336
# floors           0.137125
# waterfront       0.135648
# sqft_lot         0.050451
# condition        0.034915
# yr_built         0.021857
# yr_renovated    -0.028774
# Name: price, dtype: float64

# %%
# Boxplot 
plt.figure(figsize=(20,10))
sns.boxplot(data=df)

plt.show()

# %%
# Drop the irrelevent the features
# df = df.drop(columns=["Condition", ""])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop("price", axis=1), df["price"], test_size=0.2, random_state=42)

# %%
from category_encoders.target_encoder import TargetEncoder

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 1898         4          2         2770     45514       2           0     0
# 1370         4          3         3720     29043       2           0     0
# 3038         4          2         2810     11120       2           0     0
# 2361         4          3         4030     10800       2           0     0
# 156          3          2         2000      7000       2           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4426         3          1         1180      5002       1           0     0
# 466          4          2         2520      6000       1           0     0
# 3092         3          1         1150      8145       1           0     0
# 3772         2          1          910      2002       1           0     0
# 860          2          1         1490      3825       1           0     0
#
# ...

# %%
encoder = TargetEncoder()
X_train = encoder.fit_transform(X_train, y_train)

X_test = encoder.transform(X_test)

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 1898         4          2         2770     45514       2           0     0
# 1370         4          3         3720     29043       2           0     0
# 3038         4          2         2810     11120       2           0     0
# 2361         4          3         4030     10800       2           0     0
# 156          3          2         2000      7000       2           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4426         3          1         1180      5002       1           0     0
# 466          4          2         2520      6000       1           0     0
# 3092         3          1         1150      8145       1           0     0
# 3772         2          1          910      2002       1           0     0
# 860          2          1         1490      3825       1           0     0
#
# ...

# %%
# Model training 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import r2_score, mean_squared_error

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=42)

# %%
models = {
    "LinearRegression":LinearRegression(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "GaussianNB":GaussianNB(),
    "SVR":SVR()
}

# %%
cross_score = []
r2_score_ = []
mse_ = []
rmse_ = []

for model_name, model in models.items():

    print(f"Evaluating Model: {model_name}")

    cv_scores = cross_val_score(model, X_train, y_train, cv=kf, scoring="r2")
    cross_score.append(cv_scores)

    # Train the Model 

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Evaluate the test dataset
    r2_score_model = r2_score(y_test, y_pred)
    r2_score_.append(r2_score_model)
    mse_model = mean_squared_error(y_test, y_pred)
    mse_.append(mse_model)
    rmse_model = np.sqrt(mse_model)
    rmse_.append(rmse_model)

    print(f"\nR2 Score of {model_name}: {r2_score_model:.2f}%")
    print(f'MSE of {model_name}: {mse_model:.2f}')
    print(f"RMSE of {model_name}: {rmse_model:.2f}")
# Out:
# Evaluating Model: LinearRegression
#
# R2 Score of LinearRegression: 0.04%
# MSE of LinearRegression: 983264837838.68
# RMSE of LinearRegression: 991597.11
# Evaluating Model: DecisionTreeRegressor
#
# R2 Score of DecisionTreeRegressor: -0.01%
# MSE of DecisionTreeRegressor: 1025189105028.45
# RMSE of DecisionTreeRegressor: 1012516.22
# Evaluating Model: RandomForestRegressor
#
# R2 Score of RandomForestRegressor: 0.04%
# MSE of RandomForestRegressor: 978224761568.21
# RMSE of RandomForestRegressor: 989052.46
# Evaluating Model: GradientBoostingRegressor
#
# R2 Score of GradientBoostingRegressor: 0.05%
# MSE of GradientBoostingRegressor: 971524431176.84
# RMSE of GradientBoostingRegressor: 985659.39
# Evaluating Model: GaussianNB
#
# R2 Score of GaussianNB: 0.02%
# MSE of GaussianNB: 996451363566.96
# RMSE of GaussianNB: 998224.10
# Evaluating Model: SVR
#
# R2 Score of SVR: -0.01%
# MSE of SVR: 1033472555051.06
# RMSE of SVR: 1016598.52
